# %%
import pandas as pd
import json
import os
import math
import numpy as np
import librosa, librosa.display

# %% [markdown]
# ##**READ DATASET**

# %%
df = pd.read_csv("/content/drive/MyDrive/Music Genre/Data/features_3_sec.csv")
df.head(10)
# Out:
#             filename  length  chroma_stft_mean  ...  mfcc20_mean  mfcc20_var  label
# 0  blues.00000.0.wav   66149          0.335406  ...    -0.243027   43.771767  blues
# 1  blues.00000.1.wav   66149          0.343065  ...     5.784063   59.943081  blues
# 2  blues.00000.2.wav   66149          0.346815  ...     2.517375   33.105122  blues
# 3  blues.00000.3.wav   66149          0.363639  ...     3.630866   32.023678  blues
# 4  blues.00000.4.wav   66149          0.335579  ...     0.536961   29.146694  blues
# 5  blues.00000.5.wav   66149          0.376670  ...     3.025218   28.892687  blues
# 6  blues.00000.6.wav   66149          0.379909  ...     3.276939   25.999132  blues
# 7  blues.00000.7.wav   66149          0.331880  ...     0.210787   42.512966  blues
# 8  blues.00000.8.wav   66149          0.347877  ...     3.758598   97.618835  blues
# 9  blues.00000.9.wav   66149          0.358061  ...     0.791776   40.416420  blues
#
# [10 rows x 60 columns]

# %% [markdown]
# ##**ABOUT DATASET**

# %%
print("Dataset has",df.shape)
print("Count of Positive and Negative samples")
df.label.value_counts().reset_index()
# Out:
# Dataset has (9990, 60)
# Count of Positive and Negative samples
#        index  label
# 0        pop   1000
# 1      metal   1000
# 2      blues   1000
# 3       jazz   1000
# 4     reggae   1000
# 5      disco    999
# 6       rock    998
# 7  classical    998
# 8     hiphop    998
# 9    country    997

# %%
print("Columns with NA values are",list(df.columns[df.isnull().any()]))
# Out:
# Columns with NA values are []

# %%
df.dtypes
# Out:
# filename                    object
# length                       int64
# chroma_stft_mean           float64
# chroma_stft_var            float64
# rms_mean                   float64
# rms_var                    float64
# spectral_centroid_mean     float64
# spectral_centroid_var      float64
# spectral_bandwidth_mean    float64
# spectral_bandwidth_var     float64
# rolloff_mean               float64
# rolloff_var                float64
# zero_crossing_rate_mean    float64
# zero_crossing_rate_var     float64
# harmony_mean               float64
# harmony_var                float64
# perceptr_mean              float64
# perceptr_var               float64
# tempo                      float64
# mfcc1_mean                 float64
# mfcc1_var                  float64
# mfcc2_mean                 float64
# mfcc2_var                  float64
# mfcc3_mean                 float64
# mfcc3_var                  float64
# mfcc4_mean                 float64
# mfcc4_var                  float64
# mfcc5_mean                 float64
# mfcc5_var                  float64
# mfcc6_mean                 float64
# mfcc6_var                  float64
# mfcc7_mean                 float64
# mfcc7_var                  float64
# mfcc8_mean                 float64
# mfcc8_var                  float64
# mfcc9_mean                 float64
# mfcc9_var                  float64
# mfcc10_mean                float64
# mfcc10_var                 float64
# mfcc11_mean                float64
# mfcc11_var                 float64
# mfcc12_mean                float64
# mfcc12_var                 float64
# mfcc13_mean                float64
# mfcc13_var                 float64
# mfcc14_mean                float64
# mfcc14_var                 float64
# mfcc15_mean                float64
# mfcc15_var                 float64
# mfcc16_mean                float64
# mfcc16_var                 float64
# mfcc17_mean                float64
# mfcc17_var                 float64
# mfcc18_mean                float64
# mfcc18_var                 float64
# mfcc19_mean                float64
# mfcc19_var                 float64
# mfcc20_mean                float64
# mfcc20_var                 float64
# label                       object
# dtype: object

# %%
df = df.drop(labels="filename", axis=1)

# %%
df.head(10)
# Out:
#    length  chroma_stft_mean  chroma_stft_var  ...  mfcc20_mean  mfcc20_var  label
# 0   66149          0.335406         0.091048  ...    -0.243027   43.771767  blues
# 1   66149          0.343065         0.086147  ...     5.784063   59.943081  blues
# 2   66149          0.346815         0.092243  ...     2.517375   33.105122  blues
# 3   66149          0.363639         0.086856  ...     3.630866   32.023678  blues
# 4   66149          0.335579         0.088129  ...     0.536961   29.146694  blues
# 5   66149          0.376670         0.089702  ...     3.025218   28.892687  blues
# 6   66149          0.379909         0.088827  ...     3.276939   25.999132  blues
# 7   66149          0.331880         0.092119  ...     0.210787   42.512966  blues
# 8   66149          0.347877         0.094209  ...     3.758598   97.618835  blues
# 9   66149          0.358061         0.082957  ...     0.791776   40.416420  blues
#
# [10 rows x 59 columns]

# %% [markdown]
# ##**DATA VISUALIZATION**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Computing the Correlation Matrix
spike_cols = [col for col in df.columns if 'mean' in col]
corr = df[spike_cols].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Generate a custom diverging colormap
cmap = sns.diverging_palette(0, 25, as_cmap=True, s = 90, l = 45, n = 5)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Heatmap (for the MEAN variables)', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);
plt.savefig("Corr_Heatmap.png")

# %%
x = df[["label", "tempo"]]

fig, ax = plt.subplots(figsize=(16, 8));
sns.boxplot(x = "label", y = "tempo", data = x, palette = 'husl');

plt.title('BPM Boxplot for Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("BPM", fontsize = 15)
plt.savefig("BPM_Boxplot.png")

# %%
import sklearn.preprocessing as skp
data = df.iloc[0:, 1:]
y = data['label']
X = data.loc[:, data.columns != 'label']

# normalize
cols = X.columns
min_max_scaler = skp.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(np_scaled, columns = cols)

# Top 2 pca components
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2'])

# concatenate with target label
finalDf = pd.concat([principalDf, y], axis = 1)

plt.figure(figsize = (16, 9))
sns.scatterplot(x = "pc1", y = "pc2", data = finalDf, hue = "label", alpha = 0.7, s = 100);

plt.title('PCA on Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Principal Component 1", fontsize = 15)
plt.ylabel("Principal Component 2", fontsize = 15)
plt.savefig("PCA_Scattert.png")

# %% [markdown]
# ##**BUILDING MODEL**

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

import matplotlib.pyplot as plt
import random

import librosa
import math

# %%
DATASET_PATH = "/content/drive/MyDrive/Music Genre/Data/genres_original"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file

                file_path = os.path.join(dirpath, f)
            
                if file_path != '/content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00054.wav':

                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                
                
                    # process all segments of audio file
                    for d in range(num_segments):

                        # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        # extract mfcc
                        mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Music Genre/Data/genres_original/rock/rock.00088.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/rock/rock.00088.wav, segment:10
#
# Processing: blues
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00003.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00000.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00004.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00006.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00001.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00005.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00007.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00002.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00011.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00014.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00016.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00018.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00009.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00008.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00015.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00017.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00013.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00020.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00019.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00010.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00021.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00012.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00030.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00025.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00031.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00033.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00026.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00029.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00022.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00035.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00034.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00023.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00027.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00028.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00024.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00032.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00040.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00044.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00049.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00048.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00036.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00039.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00043.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00037.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00047.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00042.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00046.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00041.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00045.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00038.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00051.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00050.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00054.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00058.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00058.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00058.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00058.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/blues/blues.00058.wav, segment:5
# ...
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00075.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00075.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00075.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00080.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00079.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00096.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00085.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00091.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00086.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00084.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00095.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00088.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00094.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00092.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00089.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00090.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00087.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00093.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00098.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00097.wav, segment:10
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:1
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:2
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:3
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:4
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:5
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:6
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:7
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:8
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:9
# /content/drive/MyDrive/Music Genre/Data/genres_original/jazz/jazz.00099.wav, segment:10

# %%
# path to json
DATA_PATH = "/content/drive/MyDrive/Music Genre/data_10.json"

# %%
def load_data(data_path):

    with open(data_path, "r") as f:
        data = json.load(f)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
# load data
X, y = load_data(DATA_PATH)
# Out:
# Data succesfully loaded!

# %%
X.shape
# Out:
# (9986, 130, 13)

# %%
# create train, validation and test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# add an axis to input sets
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
X_train.shape
# Out:
# (7489, 130, 13, 1)

# %%
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# %%
from keras.regularizers import l2
# build the CNN
model_cnn = keras.Sequential()

# 1st conv layer
model_cnn.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model_cnn.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())


# 2nd conv layer
model_cnn.add(keras.layers.Conv2D(64, (3, 3), activation='relu',kernel_initializer='he_uniform',kernel_regularizer=l2(0.0001)))
model_cnn.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Dropout(0.3))

# 3rd conv layer
model_cnn.add(keras.layers.Conv2D(128, (2, 2), activation='relu',kernel_initializer='he_uniform',kernel_regularizer=l2(0.0001)))
model_cnn.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Dropout(0.3))

# flatten output and feed it into dense layer
model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(128, activation='relu',kernel_initializer='he_uniform',kernel_regularizer=l2(0.0001)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Dropout(0.3))

# output layer
model_cnn.add(keras.layers.Dense(10, activation='softmax'))

# %%
# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_cnn.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
callbacks = [
             EarlyStopping(patience=3)
]

# %%
model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 6, 32)        0
#  )
#
#  batch_normalization (BatchN  (None, 64, 6, 32)        128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 4, 64)         18496
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 2, 64)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 31, 2, 64)        256
#  hNormalization)
#
#  dropout (Dropout)           (None, 31, 2, 64)         0
#
#  conv2d_2 (Conv2D)           (None, 30, 1, 128)        32896
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 1, 128)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 15, 1, 128)       512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 15, 1, 128)        0
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 128)               245888
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 300,298
# Trainable params: 299,594
# Non-trainable params: 704
# _________________________________________________________________

# %%
# train model
history = model_cnn.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=100,callbacks=callbacks)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 4s 13ms/step - loss: 2.4076 - accuracy: 0.2870 - val_loss: 1.6639 - val_accuracy: 0.4229
# Epoch 2/100
# 235/235 [==============================] - 3s 13ms/step - loss: 1.9083 - accuracy: 0.3943 - val_loss: 1.5572 - val_accuracy: 0.4830
# Epoch 3/100
# 235/235 [==============================] - 3s 11ms/step - loss: 1.6761 - accuracy: 0.4552 - val_loss: 1.4477 - val_accuracy: 0.5218
# Epoch 4/100
# 235/235 [==============================] - 3s 13ms/step - loss: 1.5342 - accuracy: 0.4955 - val_loss: 1.3266 - val_accuracy: 0.5603
# Epoch 5/100
# 235/235 [==============================] - 3s 12ms/step - loss: 1.4523 - accuracy: 0.5202 - val_loss: 1.2006 - val_accuracy: 0.5955
# Epoch 6/100
# 235/235 [==============================] - 3s 12ms/step - loss: 1.3325 - accuracy: 0.5570 - val_loss: 1.2000 - val_accuracy: 0.5971
# Epoch 7/100
# 235/235 [==============================] - 3s 13ms/step - loss: 1.2665 - accuracy: 0.5736 - val_loss: 1.1028 - val_accuracy: 0.6336
# Epoch 8/100
# 235/235 [==============================] - 3s 12ms/step - loss: 1.2375 - accuracy: 0.5835 - val_loss: 1.0918 - val_accuracy: 0.6376
# Epoch 9/100
# 235/235 [==============================] - 3s 12ms/step - loss: 1.1810 - accuracy: 0.5987 - val_loss: 1.0458 - val_accuracy: 0.6572
# Epoch 10/100
# 235/235 [==============================] - 3s 13ms/step - loss: 1.1311 - accuracy: 0.6272 - val_loss: 1.0610 - val_accuracy: 0.6508
# Epoch 11/100
# 235/235 [==============================] - 3s 11ms/step - loss: 1.0818 - accuracy: 0.6391 - val_loss: 1.0005 - val_accuracy: 0.6744
# Epoch 12/100
# 235/235 [==============================] - 3s 12ms/step - loss: 1.0450 - accuracy: 0.6536 - val_loss: 0.9680 - val_accuracy: 0.6916
# Epoch 13/100
# 235/235 [==============================] - 3s 12ms/step - loss: 1.0389 - accuracy: 0.6550 - val_loss: 0.9852 - val_accuracy: 0.6752
# Epoch 14/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.9788 - accuracy: 0.6753 - val_loss: 0.9436 - val_accuracy: 0.6880
# Epoch 15/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.9663 - accuracy: 0.6803 - val_loss: 0.9265 - val_accuracy: 0.7020
# Epoch 16/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.9348 - accuracy: 0.6918 - val_loss: 0.9295 - val_accuracy: 0.6968
# Epoch 17/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.9149 - accuracy: 0.7005 - val_loss: 0.9166 - val_accuracy: 0.7028
# Epoch 18/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.8897 - accuracy: 0.7066 - val_loss: 0.9813 - val_accuracy: 0.6684
# Epoch 19/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.8725 - accuracy: 0.7133 - val_loss: 0.8608 - val_accuracy: 0.7237
# Epoch 20/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.8491 - accuracy: 0.7276 - val_loss: 0.8598 - val_accuracy: 0.7253
# Epoch 21/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.8439 - accuracy: 0.7268 - val_loss: 0.8356 - val_accuracy: 0.7329
# Epoch 22/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.8048 - accuracy: 0.7390 - val_loss: 0.8596 - val_accuracy: 0.7277
# Epoch 23/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.7964 - accuracy: 0.7390 - val_loss: 0.8182 - val_accuracy: 0.7425
# Epoch 24/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.7651 - accuracy: 0.7460 - val_loss: 0.7892 - val_accuracy: 0.7541
# Epoch 25/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.7486 - accuracy: 0.7595 - val_loss: 0.7959 - val_accuracy: 0.7493
# Epoch 26/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.7315 - accuracy: 0.7703 - val_loss: 0.7813 - val_accuracy: 0.7553
# Epoch 27/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.7245 - accuracy: 0.7705 - val_loss: 0.8211 - val_accuracy: 0.7373
# Epoch 28/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.7155 - accuracy: 0.7725 - val_loss: 0.7815 - val_accuracy: 0.7593
# Epoch 29/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6913 - accuracy: 0.7797 - val_loss: 0.7529 - val_accuracy: 0.7621
# Epoch 30/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6777 - accuracy: 0.7858 - val_loss: 0.7980 - val_accuracy: 0.7453
# Epoch 31/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6638 - accuracy: 0.7893 - val_loss: 0.8062 - val_accuracy: 0.7405
# Epoch 32/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6581 - accuracy: 0.7904 - val_loss: 0.7528 - val_accuracy: 0.7657
# Epoch 33/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6575 - accuracy: 0.7902 - val_loss: 0.7706 - val_accuracy: 0.7645
# Epoch 34/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6287 - accuracy: 0.8053 - val_loss: 0.7191 - val_accuracy: 0.7725
# Epoch 35/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6060 - accuracy: 0.8125 - val_loss: 0.7894 - val_accuracy: 0.7493
# Epoch 36/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6026 - accuracy: 0.8127 - val_loss: 0.7228 - val_accuracy: 0.7837
# Epoch 37/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6022 - accuracy: 0.8111 - val_loss: 0.7706 - val_accuracy: 0.7605

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")
    
    plt.show()


# plot accuracy and error as a function of the epochs
plot_history(history)

# %%
import pandas as pd
metrics_df = pd.DataFrame(history.history)
metrics_df.tail(10)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 27  0.715539  0.772466  0.781471      0.759311
# 28  0.691322  0.779677  0.752894      0.762115
# 29  0.677717  0.785819  0.798035      0.745294
# 30  0.663776  0.789291  0.806222      0.740489
# 31  0.658112  0.790359  0.752834      0.765719
# 32  0.657545  0.790226  0.770626      0.764517
# 33  0.628699  0.805314  0.719140      0.772527
# 34  0.605998  0.812525  0.789368      0.749299
# 35  0.602644  0.812659  0.722803      0.783740
# 36  0.602180  0.811056  0.770594      0.760513

# %%
# evaluate model on Test Set
test_loss, test_acc = model_cnn.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 79/79 - 0s - loss: 0.7706 - accuracy: 0.7605 - 331ms/epoch - 4ms/step
#
# Test accuracy: 0.7605125904083252

# %%
model_cnn.save("MusicGenre_CNN.h5")

# %%
new_model = keras.models.load_model("MusicGenre_CNN.h5")
new_model.evaluate(X_test,y_test,batch_size=128)
# Out:
# 20/20 [==============================] - 1s 42ms/step - loss: 0.7879 - accuracy: 0.7337
# [0.787862241268158, 0.7336804270744324]

# %% [markdown]
# #**TESTING ON TEST DATASET**

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[100]
y_to_predict = y_test[100]

# %%
X_to_predict.shape
# Out:
# (130, 13, 1)

# %%
# add a dimension to input data for sample - model.predict() expects a 4d array in this case
X_to_predict = X_to_predict[np.newaxis, ...] # array shape (1, 130, 13, 1)

# %%
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
# perform prediction
prediction = model_cnn.predict(X_to_predict)

# %%
# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Predicted Genre: 6

# %% [markdown]
# ####**ALL in ONE**

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[50]
y_to_predict = y_test[50]

print("Real Genre:", y_to_predict)

X_to_predict = X_to_predict[np.newaxis, ...]

prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 7
# Predicted Genre: 6

# %% [markdown]
# ####**MULTI-TESTING ON TEST DATASET**

# %%
import random
for n in range(10):

  i = random.randint(0,len(X_test))
  # pick a sample to predict from the test set
  X_to_predict = X_test[i]
  y_to_predict = y_test[i]

  print("\nReal Genre:", y_to_predict)

  X_to_predict = X_to_predict[np.newaxis, ...]

  prediction = model_cnn.predict(X_to_predict)

  # get index with max value
  predicted_index = np.argmax(prediction, axis=1)

  print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 1
# Predicted Genre: 1
#
# Real Genre: 6
# Predicted Genre: 6
#
# Real Genre: 7
# Predicted Genre: 0
#
# Real Genre: 6
# Predicted Genre: 6
#
# Real Genre: 3
# Predicted Genre: 3
#
# Real Genre: 2
# Predicted Genre: 2
#
# Real Genre: 4
# Predicted Genre: 9
#
# Real Genre: 4
# Predicted Genre: 4
#
# Real Genre: 9
# Predicted Genre: 9
#
# Real Genre: 2
# Predicted Genre: 2

# %% [markdown]
# #**TESTING with EXTERNAL DATA**

# %%
# Audio files pre-processing
def process_input(audio_file, track_duration):

  SAMPLE_RATE = 22050
  NUM_MFCC = 13
  N_FTT=2048
  HOP_LENGTH=512
  TRACK_DURATION = track_duration # measured in seconds
  SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION
  NUM_SEGMENTS = 10

  samples_per_segment = int(SAMPLES_PER_TRACK / NUM_SEGMENTS)
  num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / HOP_LENGTH)

  signal, sample_rate = librosa.load(audio_file, sr=SAMPLE_RATE)
  
  for d in range(10):

    # calculate start and finish sample for current segment
    start = samples_per_segment * d
    finish = start + samples_per_segment

    # extract mfcc
    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=NUM_MFCC, n_fft=N_FTT, hop_length=HOP_LENGTH)
    mfcc = mfcc.T

    return mfcc

# %%
genre_dict = {0:"disco ",1:"pop",2:"classical",3:"metal",4:"rock",5:"blues",6:"hiphop",7:"reggae",8:"country",9:"jazz"}

# %%
new_input_mfcc = process_input("/content/drive/MyDrive/Music Genre/wav_files/blues.00000.wav", 30)

# %%
type(new_input_mfcc)
# Out:
# numpy.ndarray

# %%
new_input_mfcc.shape
# Out:
# (130, 13)

# %%
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# Predicted Genre: rock
