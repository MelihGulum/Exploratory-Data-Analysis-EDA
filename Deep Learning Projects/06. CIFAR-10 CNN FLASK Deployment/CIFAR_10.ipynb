# %% [markdown]
# ## **Import Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization

from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Load Dataset**

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# 170508288/170498071 [==============================] - 13s 0us/step

# %%
print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %% [markdown]
# ## **Visualization**

# %%
# create a grid of 3x3 images
plt.figure(figsize=(8,8))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    img = x_train[i]
    plt.imshow(img)
    
# show the plot
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5)) 
# Count plot for training set
sns.countplot(y_train.ravel(), ax=axs[0])
axs[0].set_title('Distribution of training data')
axs[0].set_xlabel('Classes')
# Count plot for testing set
sns.countplot(y_test.ravel(), ax=axs[1])
axs[1].set_title('Distribution of Testing data')
axs[1].set_xlabel('Classes')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## **Preprocess and Splitting**

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

datagen = ImageDataGenerator(
                            rotation_range=15,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=True,
)

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0)

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10)
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val  = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (5000, 10)
# (5000, 10)

# %% [markdown]
# ## **Graph**

# %%
def results(model):
  epoch = 93

  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Classification Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Classification Accuracy")
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Model loss")
  plt.show()

# %% [markdown]
# ##**Model**

# %%
weight_decay = 1e-4
model = Sequential([
                    Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
                    BatchNormalization(),
                    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.2),

                    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),

                    Conv2D(256, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(256, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.4),

                    Flatten(),
                    Dense(256, activation='relu'),
                    BatchNormalization(),
                    Dropout(0.5),
                    Dense(10, activation='softmax')                    
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2,201,418
# Trainable params: 2,199,114
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
opt =    tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
callbacks = [ ReduceLROnPlateau(monitor='val_loss', 
                                patience=10,
                                cooldown=1,
                                verbose=1),
              EarlyStopping(monitor='val_loss',
                            min_delta=1e-4,
                            patience=15)]

# %%
epoch = 200
history = model.fit(datagen.flow(x_train , y_train , batch_size = 64), epochs = epoch, steps_per_epoch=len(x_train)/64, validation_data = (x_val , y_val) , verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/200
# 781/781 [==============================] - 43s 39ms/step - loss: 1.7586 - accuracy: 0.4345 - val_loss: 1.4967 - val_accuracy: 0.5336 - lr: 0.0010
# Epoch 2/200
# 781/781 [==============================] - 28s 36ms/step - loss: 1.1717 - accuracy: 0.6121 - val_loss: 1.3488 - val_accuracy: 0.6146 - lr: 0.0010
# Epoch 3/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.9984 - accuracy: 0.6844 - val_loss: 1.0022 - val_accuracy: 0.7034 - lr: 0.0010
# Epoch 4/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.9124 - accuracy: 0.7237 - val_loss: 0.8809 - val_accuracy: 0.7510 - lr: 0.0010
# Epoch 5/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8647 - accuracy: 0.7513 - val_loss: 0.9117 - val_accuracy: 0.7470 - lr: 0.0010
# Epoch 6/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.8394 - accuracy: 0.7681 - val_loss: 0.9009 - val_accuracy: 0.7616 - lr: 0.0010
# Epoch 7/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.8240 - accuracy: 0.7822 - val_loss: 0.8281 - val_accuracy: 0.7930 - lr: 0.0010
# Epoch 8/200
# 781/781 [==============================] - 30s 39ms/step - loss: 0.8141 - accuracy: 0.7931 - val_loss: 0.8752 - val_accuracy: 0.7886 - lr: 0.0010
# Epoch 9/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8039 - accuracy: 0.8048 - val_loss: 0.8619 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 10/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8024 - accuracy: 0.8115 - val_loss: 0.8441 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 11/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7985 - accuracy: 0.8152 - val_loss: 0.8425 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 12/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7908 - accuracy: 0.8198 - val_loss: 0.7356 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 13/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7798 - accuracy: 0.8248 - val_loss: 0.7810 - val_accuracy: 0.8280 - lr: 0.0010
# Epoch 14/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7751 - accuracy: 0.8298 - val_loss: 0.8094 - val_accuracy: 0.8310 - lr: 0.0010
# Epoch 15/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7678 - accuracy: 0.8342 - val_loss: 0.8179 - val_accuracy: 0.8254 - lr: 0.0010
# Epoch 16/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7696 - accuracy: 0.8350 - val_loss: 0.7790 - val_accuracy: 0.8420 - lr: 0.0010
# Epoch 17/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7627 - accuracy: 0.8394 - val_loss: 0.7574 - val_accuracy: 0.8510 - lr: 0.0010
# Epoch 18/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7629 - accuracy: 0.8401 - val_loss: 0.8092 - val_accuracy: 0.8332 - lr: 0.0010
# Epoch 19/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7547 - accuracy: 0.8434 - val_loss: 0.8245 - val_accuracy: 0.8282 - lr: 0.0010
# Epoch 20/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.7547 - accuracy: 0.8455 - val_loss: 0.7976 - val_accuracy: 0.8298 - lr: 0.0010
# Epoch 21/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7474 - accuracy: 0.8488 - val_loss: 0.8545 - val_accuracy: 0.8280 - lr: 0.0010
# Epoch 22/200
# 781/781 [============================>.] - ETA: 0s - loss: 0.7373 - accuracy: 0.8508
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 781/781 [==============================] - 27s 35ms/step - loss: 0.7372 - accuracy: 0.8508 - val_loss: 0.7446 - val_accuracy: 0.8556 - lr: 0.0010
# Epoch 23/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6673 - accuracy: 0.8745 - val_loss: 0.6457 - val_accuracy: 0.8842 - lr: 1.0000e-04
# Epoch 24/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6278 - accuracy: 0.8857 - val_loss: 0.6250 - val_accuracy: 0.8884 - lr: 1.0000e-04
# Epoch 25/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.6028 - accuracy: 0.8898 - val_loss: 0.6080 - val_accuracy: 0.8916 - lr: 1.0000e-04
# Epoch 26/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5848 - accuracy: 0.8929 - val_loss: 0.6011 - val_accuracy: 0.8936 - lr: 1.0000e-04
# Epoch 27/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.5694 - accuracy: 0.8952 - val_loss: 0.5922 - val_accuracy: 0.8920 - lr: 1.0000e-04
# Epoch 28/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5571 - accuracy: 0.8997 - val_loss: 0.5653 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 29/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5421 - accuracy: 0.9001 - val_loss: 0.5651 - val_accuracy: 0.8990 - lr: 1.0000e-04
# Epoch 30/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5311 - accuracy: 0.9028 - val_loss: 0.5621 - val_accuracy: 0.8980 - lr: 1.0000e-04
# Epoch 31/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5214 - accuracy: 0.9051 - val_loss: 0.5538 - val_accuracy: 0.8974 - lr: 1.0000e-04
# Epoch 32/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5157 - accuracy: 0.9051 - val_loss: 0.5457 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 33/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.5022 - accuracy: 0.9097 - val_loss: 0.5480 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 34/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4981 - accuracy: 0.9081 - val_loss: 0.5436 - val_accuracy: 0.8996 - lr: 1.0000e-04
# Epoch 35/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4857 - accuracy: 0.9118 - val_loss: 0.5432 - val_accuracy: 0.8982 - lr: 1.0000e-04
# Epoch 36/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4796 - accuracy: 0.9109 - val_loss: 0.5221 - val_accuracy: 0.9040 - lr: 1.0000e-04
# Epoch 37/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.4755 - accuracy: 0.9123 - val_loss: 0.5246 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 38/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4715 - accuracy: 0.9109 - val_loss: 0.5214 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 39/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4599 - accuracy: 0.9140 - val_loss: 0.5191 - val_accuracy: 0.9030 - lr: 1.0000e-04
# Epoch 40/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4527 - accuracy: 0.9158 - val_loss: 0.5187 - val_accuracy: 0.9036 - lr: 1.0000e-04
# Epoch 41/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4476 - accuracy: 0.9162 - val_loss: 0.5133 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 42/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4428 - accuracy: 0.9171 - val_loss: 0.5125 - val_accuracy: 0.9036 - lr: 1.0000e-04
# Epoch 43/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4330 - accuracy: 0.9203 - val_loss: 0.5048 - val_accuracy: 0.9060 - lr: 1.0000e-04
# Epoch 44/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4324 - accuracy: 0.9191 - val_loss: 0.4945 - val_accuracy: 0.9068 - lr: 1.0000e-04
# Epoch 45/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4256 - accuracy: 0.9213 - val_loss: 0.4915 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 46/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.4185 - accuracy: 0.9220 - val_loss: 0.4862 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 47/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4116 - accuracy: 0.9252 - val_loss: 0.4872 - val_accuracy: 0.9098 - lr: 1.0000e-04
# Epoch 48/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4138 - accuracy: 0.9214 - val_loss: 0.4737 - val_accuracy: 0.9136 - lr: 1.0000e-04
# Epoch 49/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4074 - accuracy: 0.9231 - val_loss: 0.4944 - val_accuracy: 0.9062 - lr: 1.0000e-04
# Epoch 50/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.4024 - accuracy: 0.9242 - val_loss: 0.4952 - val_accuracy: 0.9060 - lr: 1.0000e-04
# Epoch 51/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3997 - accuracy: 0.9247 - val_loss: 0.4807 - val_accuracy: 0.9052 - lr: 1.0000e-04
# Epoch 52/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.4000 - accuracy: 0.9242 - val_loss: 0.4760 - val_accuracy: 0.9114 - lr: 1.0000e-04
# Epoch 53/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3960 - accuracy: 0.9257 - val_loss: 0.4531 - val_accuracy: 0.9126 - lr: 1.0000e-04
# Epoch 54/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3899 - accuracy: 0.9263 - val_loss: 0.4672 - val_accuracy: 0.9104 - lr: 1.0000e-04
# Epoch 55/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3779 - accuracy: 0.9297 - val_loss: 0.4755 - val_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 56/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.3796 - accuracy: 0.9281 - val_loss: 0.4906 - val_accuracy: 0.9046 - lr: 1.0000e-04
# Epoch 57/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3787 - accuracy: 0.9278 - val_loss: 0.4674 - val_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 58/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3749 - accuracy: 0.9293 - val_loss: 0.4841 - val_accuracy: 0.9064 - lr: 1.0000e-04
# Epoch 59/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3668 - accuracy: 0.9319 - val_loss: 0.4727 - val_accuracy: 0.9102 - lr: 1.0000e-04
# Epoch 60/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3650 - accuracy: 0.9308 - val_loss: 0.4813 - val_accuracy: 0.9048 - lr: 1.0000e-04
# Epoch 61/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3626 - accuracy: 0.9317 - val_loss: 0.4623 - val_accuracy: 0.9114 - lr: 1.0000e-04
# Epoch 62/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3609 - accuracy: 0.9328 - val_loss: 0.4600 - val_accuracy: 0.9096 - lr: 1.0000e-04
# Epoch 63/200
# 781/781 [============================>.] - ETA: 0s - loss: 0.3570 - accuracy: 0.9323
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3571 - accuracy: 0.9323 - val_loss: 0.4637 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 64/200
# 781/781 [==============================] - 27s 35ms/step - loss: 0.3495 - accuracy: 0.9348 - val_loss: 0.4501 - val_accuracy: 0.9130 - lr: 1.0000e-05
# Epoch 65/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3445 - accuracy: 0.9365 - val_loss: 0.4509 - val_accuracy: 0.9154 - lr: 1.0000e-05
# Epoch 66/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3443 - accuracy: 0.9361 - val_loss: 0.4490 - val_accuracy: 0.9138 - lr: 1.0000e-05
# Epoch 67/200
# 781/781 [==============================] - 29s 38ms/step - loss: 0.3420 - accuracy: 0.9377 - val_loss: 0.4494 - val_accuracy: 0.9142 - lr: 1.0000e-05
# Epoch 68/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3402 - accuracy: 0.9375 - val_loss: 0.4467 - val_accuracy: 0.9138 - lr: 1.0000e-05
# Epoch 69/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3383 - accuracy: 0.9384 - val_loss: 0.4452 - val_accuracy: 0.9126 - lr: 1.0000e-05
# Epoch 70/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3390 - accuracy: 0.9386 - val_loss: 0.4461 - val_accuracy: 0.9142 - lr: 1.0000e-05
# Epoch 71/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3337 - accuracy: 0.9411 - val_loss: 0.4428 - val_accuracy: 0.9156 - lr: 1.0000e-05
# Epoch 72/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3356 - accuracy: 0.9387 - val_loss: 0.4493 - val_accuracy: 0.9148 - lr: 1.0000e-05
# Epoch 73/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3368 - accuracy: 0.9380 - val_loss: 0.4463 - val_accuracy: 0.9158 - lr: 1.0000e-05
# Epoch 74/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3356 - accuracy: 0.9397 - val_loss: 0.4453 - val_accuracy: 0.9160 - lr: 1.0000e-05
# Epoch 75/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3312 - accuracy: 0.9409 - val_loss: 0.4447 - val_accuracy: 0.9158 - lr: 1.0000e-05
# Epoch 76/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.3316 - accuracy: 0.9401 - val_loss: 0.4459 - val_accuracy: 0.9158 - lr: 1.0000e-05
# Epoch 77/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3313 - accuracy: 0.9416 - val_loss: 0.4435 - val_accuracy: 0.9162 - lr: 1.0000e-05
# Epoch 78/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3320 - accuracy: 0.9403 - val_loss: 0.4381 - val_accuracy: 0.9164 - lr: 1.0000e-05
# Epoch 79/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3342 - accuracy: 0.9394 - val_loss: 0.4422 - val_accuracy: 0.9146 - lr: 1.0000e-05
# Epoch 80/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3274 - accuracy: 0.9407 - val_loss: 0.4447 - val_accuracy: 0.9146 - lr: 1.0000e-05
# Epoch 81/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3251 - accuracy: 0.9424 - val_loss: 0.4407 - val_accuracy: 0.9160 - lr: 1.0000e-05
# Epoch 82/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3221 - accuracy: 0.9434 - val_loss: 0.4411 - val_accuracy: 0.9160 - lr: 1.0000e-05
# Epoch 83/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3277 - accuracy: 0.9409 - val_loss: 0.4427 - val_accuracy: 0.9154 - lr: 1.0000e-05
# Epoch 84/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3291 - accuracy: 0.9401 - val_loss: 0.4481 - val_accuracy: 0.9140 - lr: 1.0000e-05
# Epoch 85/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3234 - accuracy: 0.9425 - val_loss: 0.4442 - val_accuracy: 0.9154 - lr: 1.0000e-05
# Epoch 86/200
# 781/781 [==============================] - 29s 37ms/step - loss: 0.3266 - accuracy: 0.9413 - val_loss: 0.4458 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 87/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3220 - accuracy: 0.9418 - val_loss: 0.4457 - val_accuracy: 0.9158 - lr: 1.0000e-05
# Epoch 88/200
# 782/781 [==============================] - ETA: 0s - loss: 0.3250 - accuracy: 0.9422
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3250 - accuracy: 0.9422 - val_loss: 0.4431 - val_accuracy: 0.9164 - lr: 1.0000e-05
# Epoch 89/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3228 - accuracy: 0.9427 - val_loss: 0.4394 - val_accuracy: 0.9166 - lr: 1.0000e-06
# Epoch 90/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3245 - accuracy: 0.9431 - val_loss: 0.4404 - val_accuracy: 0.9172 - lr: 1.0000e-06
# Epoch 91/200
# 781/781 [==============================] - 28s 35ms/step - loss: 0.3231 - accuracy: 0.9421 - val_loss: 0.4431 - val_accuracy: 0.9152 - lr: 1.0000e-06
# Epoch 92/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3170 - accuracy: 0.9453 - val_loss: 0.4404 - val_accuracy: 0.9150 - lr: 1.0000e-06
# Epoch 93/200
# 781/781 [==============================] - 28s 36ms/step - loss: 0.3182 - accuracy: 0.9438 - val_loss: 0.4400 - val_accuracy: 0.9168 - lr: 1.0000e-06

# %% [markdown]
# ## **Results and Save**

# %%
acc = model.evaluate(x_test , y_test)
print("test set loss : " , acc[0])
print("test set accuracy :", acc[1]*100)
# Out:
# 157/157 [==============================] - 1s 5ms/step - loss: 0.4180 - accuracy: 0.9174
# test set loss :  0.41801831126213074
# test set accuracy : 91.74000024795532

# %%
results(model)

# %%
model.save("CNN-91.74.h5")
